# %% [markdown]
# # SDG Indicator 3.3.2 - Tuberculosis incidence per 1,000 population

# %% [markdown]
# **Goal 3**: Ensure healthy lives and promote well-being for all at all ages
#
#
# **Target 3.3**: By 2030, end the epidemics of AIDS, tuberculosis, malaria and neglected tropical diseases and
# combat hepatitis, water-borne diseases and other communicable diseases
#
# The tuberculosis incidence per 100,000 population as defined as the estimated number of new and
# relapse TB cases (all forms of TB, including cases in people living with HIV) arising in a given year,
# expressed as a rate per 100 000 population.
#
# **Source**: https://unstats.un.org/sdgs/metadata/files/Metadata-03-03-02.pdf
#
# **Documentation**: http://www.who.int/publications/guidelines/tuberculosis/en/

# %%
# %load ../../snippets/imports
import pandas as pd
import numpy as np
from pandas import DataFrame, Series

import matplotlib.pyplot as plt
# %matplotlib inline

import os
import urllib

# %% [markdown]
# ## Data
#
# * http://www.who.int/tb/country/data/download/en/

# %%
# %load ../../snippets/dataroot
data_root = "../../data/03.3.2"

if not os.path.exists(data_root):
    os.makedirs(data_root)

# %% [markdown]
# ### Data Dictionary
#
# * https://extranet.who.int/tme/generateCSV.asp?ds=dictionary

# %%
# download to a local directory - to avoid re-requesting across notebook sessions
dd_source_path = "https://extranet.who.int/tme/generateCSV.asp?ds=dictionary"
dd_dest_path = "{0}/who_tb_dd.csv".format(data_root)

# NOTE: uncomment to download csv from source
#urllib.request.urlretrieve (dd_source_path, dd_dest_path)

# %%
dd = pd.read_csv(dd_dest_path)
dd.head()
# Out:
#             variable_name               dataset code_list  \
# 0                     bmu  Community engagement       NaN
# 1      bmu_community_impl  Community engagement       NaN
# 2            bmu_ref_data  Community engagement       NaN
# 3      bmu_rxsupport_data  Community engagement       NaN
# 4  bmu_rxsupport_data_coh  Community engagement       NaN
#
#                                           definition
# 0  Number of TB Basic Management Units in the cou...
# 1  Number of TB Basic Management Units which impl...
# 2  Number of Basic Management Units with data on ...
# 3  Number of Basic Management Units with data on ...
# 4  Total number of patients who started TB treatm...

# %% [markdown]
# ### WHO TB Burden Estimates
#
# * https://extranet.who.int/tme/generateCSV.asp?ds=estimates

# %%
who_tme_source_path = "https://extranet.who.int/tme/generateCSV.asp?ds=estimates"
who_tme_dest_path = "{0}/who_tme_est.csv".format(data_root)

# NOTE: uncomment to download csv from source
#urllib.request.urlretrieve(who_tme_source_path, who_tme_dest_path)

# %%
tme = pd.read_csv(who_tme_dest_path)
tme.head()
# Out:
#        country iso2 iso3  iso_numeric g_whoregion  year  e_pop_num  \
# 0  Afghanistan   AF  AFG            4         EMR  2000   20093756
# 1  Afghanistan   AF  AFG            4         EMR  2001   20966463
# 2  Afghanistan   AF  AFG            4         EMR  2002   21979923
# 3  Afghanistan   AF  AFG            4         EMR  2003   23064851
# 4  Afghanistan   AF  AFG            4         EMR  2004   24118979
#
#    e_inc_100k  e_inc_100k_lo  e_inc_100k_hi    ...     e_mort_num  \
# 0       190.0          123.0          271.0    ...          14000
# 1       189.0          123.0          271.0    ...          13000
# 2       189.0          122.0          270.0    ...          12000
# 3       189.0          122.0          270.0    ...          13000
# 4       189.0          122.0          270.0    ...          12000
#
#    e_mort_num_lo  e_mort_num_hi  cfr  cfr_lo  cfr_hi  c_newinc_100k  c_cdr  \
# 0           7900          21000  NaN     NaN     NaN           35.0   19.0
# 1           7600          20000  NaN     NaN     NaN           48.0   26.0
# 2           7200          19000  NaN     NaN     NaN           63.0   33.0
# 3           7700          20000  NaN     NaN     NaN           60.0   32.0
# 4           7200          19000  NaN     NaN     NaN           76.0   40.0
#
#    c_cdr_lo  c_cdr_hi
# 0      13.0      29.0
# 1      18.0      39.0
# 2      23.0      51.0
# 3      22.0      49.0
# 4      28.0      62.0
#
# [5 rows x 71 columns]

# %%
tme.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3651 entries, 0 to 3650
# Data columns (total 71 columns):
# country                     3651 non-null object
# iso2                        3634 non-null object
# iso3                        3651 non-null object
# iso_numeric                 3651 non-null int64
# g_whoregion                 3651 non-null object
# year                        3651 non-null int64
# e_pop_num                   3651 non-null int64
# e_inc_100k                  3651 non-null float64
# e_inc_100k_lo               3651 non-null float64
# e_inc_100k_hi               3651 non-null float64
# e_inc_num                   3651 non-null int64
# e_inc_num_lo                3651 non-null int64
# e_inc_num_hi                3651 non-null int64
# e_inc_num_f014              217 non-null float64
# e_inc_num_f014_lo           209 non-null float64
# e_inc_num_f014_hi           209 non-null float64
# e_inc_num_f15plus           217 non-null float64
# e_inc_num_f15plus_lo        209 non-null float64
# e_inc_num_f15plus_hi        209 non-null float64
# e_inc_num_f                 217 non-null float64
# e_inc_num_f_lo              209 non-null float64
# e_inc_num_f_hi              209 non-null float64
# e_inc_num_m014              217 non-null float64
# e_inc_num_m014_lo           209 non-null float64
# e_inc_num_m014_hi           209 non-null float64
# e_inc_num_m15plus           217 non-null float64
# e_inc_num_m15plus_lo        209 non-null float64
# e_inc_num_m15plus_hi        209 non-null float64
# e_inc_num_m                 217 non-null float64
# e_inc_num_m_lo              209 non-null float64
# e_inc_num_m_hi              209 non-null float64
# e_inc_num_014               217 non-null float64
# e_inc_num_014_lo            209 non-null float64
# e_inc_num_014_hi            209 non-null float64
# e_inc_num_15plus            217 non-null float64
# e_inc_num_15plus_lo         209 non-null float64
# e_inc_num_15plus_hi         209 non-null float64
# e_tbhiv_prct                3316 non-null float64
# e_tbhiv_prct_lo             3316 non-null float64
# e_tbhiv_prct_hi             3316 non-null float64
# e_inc_tbhiv_100k            3316 non-null float64
# e_inc_tbhiv_100k_lo         3313 non-null float64
# e_inc_tbhiv_100k_hi         3313 non-null float64
# e_inc_tbhiv_num             3316 non-null float64
# e_inc_tbhiv_num_lo          3313 non-null float64
# e_inc_tbhiv_num_hi          3313 non-null float64
# e_mort_exc_tbhiv_100k       3651 non-null float64
# e_mort_exc_tbhiv_100k_lo    3650 non-null float64
# e_mort_exc_tbhiv_100k_hi    3650 non-null float64
# e_mort_exc_tbhiv_num        3651 non-null int64
# e_mort_exc_tbhiv_num_lo     3650 non-null float64
# e_mort_exc_tbhiv_num_hi     3650 non-null float64
# e_mort_tbhiv_100k           3651 non-null float64
# e_mort_tbhiv_100k_lo        3635 non-null float64
# e_mort_tbhiv_100k_hi        3635 non-null float64
# e_mort_tbhiv_num            3651 non-null int64
# e_mort_tbhiv_num_lo         3635 non-null float64
# e_mort_tbhiv_num_hi         3635 non-null float64
# e_mort_100k                 3651 non-null float64
# e_mort_100k_lo              3651 non-null float64
# e_mort_100k_hi              3651 non-null float64
# e_mort_num                  3651 non-null int64
# e_mort_num_lo               3651 non-null int64
# e_mort_num_hi               3651 non-null int64
# cfr                         205 non-null float64
# cfr_lo                      205 non-null float64
# cfr_hi                      205 non-null float64
# c_newinc_100k               3484 non-null float64
# c_cdr                       3400 non-null float64
# c_cdr_lo                    3400 non-null float64
# c_cdr_hi                    3400 non-null float64
# dtypes: float64(56), int64(11), object(4)
# memory usage: 2.0+ MB

# %%
tme.e_inc_100k.describe()
# Out:
# count    3651.000000
# mean      126.024314
# std       183.206878
# min         0.000000
# 25%        13.000000
# 50%        50.000000
# 75%       163.000000
# max      1280.000000
# Name: e_inc_100k, dtype: float64

# %%
m_2016 = tme.year == 2016

# %%
tme[m_2016].e_inc_100k.describe()
# Out:
# count    217.000000
# mean     103.909631
# std      143.625535
# min        0.000000
# 25%        9.000000
# 50%       46.000000
# 75%      145.000000
# max      781.000000
# Name: e_inc_100k, dtype: float64

# %%
cols = ['country', 'e_inc_100k'] #, 'e_inc_100k_lo', 'e_inc_100k_hi']
tme.loc[m_2016, cols].sort_values(by='e_inc_100k', ascending=False)
# Out:
#                                     country  e_inc_100k
# 3000                           South Africa      781.00
# 1832                                Lesotho      724.00
# 1730                               Kiribati      566.00
# 2551                            Philippines      554.00
# 2184                             Mozambique      551.00
# 948   Democratic People's Republic of Korea      513.00
# 3208                            Timor-Leste      498.00
# 1237                                  Gabon      485.00
# 2218                                Namibia      446.00
# 2500                       Papua New Guinea      432.00
# 2019                       Marshall Islands      422.00
# 669                Central African Republic      407.00
# 3091                              Swaziland      398.00
# 1543                              Indonesia      391.00
# 805                                   Congo      378.00
# 3633                                 Zambia      376.00
# 1424                          Guinea-Bissau      374.00
# 101                                  Angola      370.00
# 2201                                Myanmar      361.00
# 1713                                  Kenya      348.00
# 601                                Cambodia      345.00
# 999                                Djibouti      335.00
# 465                                Botswana      326.00
# 965        Democratic Republic of the Congo      323.00
# 1849                                Liberia      308.00
# 2891                           Sierra Leone      304.00
# 3446            United Republic of Tanzania      287.00
# 2983                                Somalia      270.00
# 2449                               Pakistan      268.00
# 1917                             Madagascar      237.00
# ...                                     ...         ...
# 2279                            Netherlands        5.90
# 1900                             Luxembourg        5.80
# 652                          Cayman Islands        5.70
# 1679                                 Jordan        5.60
# 914                                  Cyprus        5.60
# 635                                  Canada        5.20
# 931                                 Czechia        5.00
# 1186                                Finland        4.70
# 431       Bonaire, Saint Eustatius and Saba        4.60
# 1645                                Jamaica        4.50
# 1322                                 Greece        4.40
# 390                                 Bermuda        3.70
# 1611                                 Israel        3.50
# 135                     Antigua and Barbuda        3.40
# 3463               United States of America        3.10
# 897                                 Curaçao        2.90
# 1509                                Iceland        2.10
# 2602                            Puerto Rico        2.00
# 2738                            Saint Lucia        1.90
# 305                                Barbados        1.20
# 3599               West Bank and Gaza Strip        1.00
# 3412                   United Arab Emirates        0.79
# 3582              Wallis and Futuna Islands        0.00
# 3242                                Tokelau        0.00
# 2789                             San Marino        0.00
# 2104                                 Monaco        0.00
# 2150                             Montserrat        0.00
# 2915              Sint Maarten (Dutch part)        0.00
# 2721                  Saint Kitts and Nevis        0.00
# 499                  British Virgin Islands        0.00
#
# [217 rows x 2 columns]
